# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
#to ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
files= ['loan_details.csv', 'Employment_details.csv', 'personal_details.csv']

# %%
#merging the three files together

df= pd.DataFrame()
for file in files:
    data= pd.read_csv(file)
    df= pd.concat([df, data], axis = 0)
df.to_csv('merged_files.csv', index = False)

# %%
# Read the Merged data

df= pd.read_csv("merged_files.csv")
df
# Out:
# C:\Users\kanki\AppData\Local\Temp\ipykernel_1960\45038229.py:3: DtypeWarning: Columns (4,5,6,9,10,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv("merged_files.csv")
#            Id  LoanAmount applied for (in thoudands)  Loan_Amount_Duration  \
# 0       31453                                  400.0                 360.0
# 1       21375                                  438.0                 360.0
# 2       27992                                  214.0                 360.0
# 3        3326                                  128.0                 360.0
# 4       22227                                  116.0                  84.0
# ...       ...                                    ...                   ...
# 143563  47852                                    NaN                   NaN
# 143564  47853                                    NaN                   NaN
# 143565  47854                                    NaN                   NaN
# 143566  47855                                    NaN                   NaN
# 143567  47856                                    NaN                   NaN
#
#         Credit_History Property_Area Loan_Status Self_Employed  \
# 0                  1.0     Semiurban           Y           NaN
# 1                  1.0     Semiurban           Y           NaN
# 2                  1.0         Urban           Y           NaN
# 3                  1.0         Urban           Y           NaN
# 4                  0.0         Urban           N           NaN
# ...                ...           ...         ...           ...
# 143563             NaN           NaN         NaN           NaN
# 143564             NaN           NaN         NaN           NaN
# 143565             NaN           NaN         NaN           NaN
# 143566             NaN           NaN         NaN           NaN
# 143567             NaN           NaN         NaN           NaN
#
#         Income of applicant  Income of coapplicant  Gender Marital Status  \
# 0                       NaN                    NaN     NaN            NaN
# 1                       NaN                    NaN     NaN            NaN
# 2                       NaN                    NaN     NaN            NaN
# 3                       NaN                    NaN     NaN            NaN
# 4                       NaN                    NaN     NaN            NaN
# ...                     ...                    ...     ...            ...
# 143563                  NaN                    NaN    Male            Yes
# 143564                  NaN                    NaN    Male            Yes
# 143565                  NaN                    NaN  Female             No
# 143566                  NaN                    NaN    Male            Yes
# 143567                  NaN                    NaN    Male            Yes
#
#        Family members Status of education
# 0                 NaN                 NaN
# 1                 NaN                 NaN
# 2                 NaN                 NaN
# 3                 NaN                 NaN
# 4                 NaN                 NaN
# ...               ...                 ...
# 143563              0            Graduate
# 143564             3+        Not Graduate
# 143565              0            Graduate
# 143566             3+            Graduate
# 143567              0            Graduate
#
# [143568 rows x 13 columns]

# %%
#Getting the info about the merged data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143568 entries, 0 to 143567
# Data columns (total 13 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   Id                                     143568 non-null  int64
#  1   LoanAmount applied for (in thoudands)  45660 non-null   float64
#  2   Loan_Amount_Duration                   46367 non-null   float64
#  3   Credit_History                         44409 non-null   float64
#  4   Property_Area                          47856 non-null   object
#  5   Loan_Status                            47856 non-null   object
#  6   Self_Employed                          45311 non-null   object
#  7   Income of applicant                    47856 non-null   float64
#  8   Income of coapplicant                  47856 non-null   float64
#  9   Gender                                 46676 non-null   object
#  10  Marital Status                         47856 non-null   object
#  11  Family members                         46615 non-null   object
#  12  Status of education                    47856 non-null   object
# dtypes: float64(5), int64(1), object(7)
# memory usage: 14.2+ MB

# %%
df.describe()
# Out:
#                   Id  LoanAmount applied for (in thoudands)  \
# count  143568.000000                           45660.000000
# mean    23928.500000                             135.906789
# std     13814.885351                              70.156703
# min         1.000000                              30.000000
# 25%     11964.750000                             100.000000
# 50%     23928.500000                             125.000000
# 75%     35892.250000                             160.000000
# max     47856.000000                             481.000000
#
#        Loan_Amount_Duration  Credit_History  Income of applicant  \
# count          46367.000000    44409.000000         47856.000000
# mean             343.222658        0.829539          4854.436748
# std               61.561339        0.376041          3900.875350
# min               84.000000        0.000000          1064.000000
# 25%              360.000000        1.000000          2666.000000
# 50%              360.000000        1.000000          3660.000000
# 75%              360.000000        1.000000          5566.000000
# max              480.000000        1.000000         25515.000000
#
#        Income of coapplicant
# count           47856.000000
# mean             1664.988486
# std              1910.643113
# min                 0.000000
# 25%                 0.000000
# 50%              1387.000000
# 75%              2583.000000
# max              8610.000000

# %%
# Changing Family members column to from object to float

df['Family members'] = pd.to_numeric(df['Family members'], errors= 'coerce')
df.dtypes['Family members']
# Out:
# dtype('float64')

# %%
df.dtypes
# Out:
# Id                                         int64
# LoanAmount applied for (in thoudands)    float64
# Loan_Amount_Duration                     float64
# Credit_History                           float64
# Property_Area                             object
# Loan_Status                               object
# Self_Employed                             object
# Income of applicant                      float64
# Income of coapplicant                    float64
# Gender                                    object
# Marital Status                            object
# Family members                           float64
# Status of education                       object
# dtype: object

# %%
#To check the null values

df.isnull()
# Out:
#            Id  LoanAmount applied for (in thoudands)  Loan_Amount_Duration  \
# 0       False                                  False                 False
# 1       False                                  False                 False
# 2       False                                  False                 False
# 3       False                                  False                 False
# 4       False                                  False                 False
# ...       ...                                    ...                   ...
# 143563  False                                   True                  True
# 143564  False                                   True                  True
# 143565  False                                   True                  True
# 143566  False                                   True                  True
# 143567  False                                   True                  True
#
#         Credit_History  Property_Area  Loan_Status  Self_Employed  \
# 0                False          False        False           True
# 1                False          False        False           True
# 2                False          False        False           True
# 3                False          False        False           True
# 4                False          False        False           True
# ...                ...            ...          ...            ...
# 143563            True           True         True           True
# 143564            True           True         True           True
# 143565            True           True         True           True
# 143566            True           True         True           True
# 143567            True           True         True           True
#
#         Income of applicant  Income of coapplicant  Gender  Marital Status  \
# 0                      True                   True    True            True
# 1                      True                   True    True            True
# 2                      True                   True    True            True
# 3                      True                   True    True            True
# 4                      True                   True    True            True
# ...                     ...                    ...     ...             ...
# 143563                 True                   True   False           False
# 143564                 True                   True   False           False
# 143565                 True                   True   False           False
# 143566                 True                   True   False           False
# 143567                 True                   True   False           False
#
#         Family members  Status of education
# 0                 True                 True
# 1                 True                 True
# 2                 True                 True
# 3                 True                 True
# 4                 True                 True
# ...                ...                  ...
# 143563           False                False
# 143564           False                False
# 143565           False                False
# 143566           False                False
# 143567           False                False
#
# [143568 rows x 13 columns]

# %%
#Check if missing values and outliers are there
df.isnull().sum()
# Out:
# Id                                            0
# LoanAmount applied for (in thoudands)     97908
# Loan_Amount_Duration                      97201
# Credit_History                            99159
# Property_Area                             95712
# Loan_Status                               95712
# Self_Employed                             98257
# Income of applicant                       95712
# Income of coapplicant                     95712
# Gender                                    96892
# Marital Status                            95712
# Family members                           100602
# Status of education                       95712
# dtype: int64

# %%
#checking the outlier with the Z-score
from scipy import stats

z_scores = stats.zscore(df['LoanAmount applied for (in thoudands)'])
threshold= 3
outliers = df['LoanAmount applied for (in thoudands)'][abs(z_scores)> threshold]
print(outliers)


z_scores = stats.zscore(df['Loan_Amount_Duration'])
threshold= 3
outliers = df['Loan_Amount_Duration'][abs(z_scores)> threshold]
print(outliers)

z_scores = stats.zscore(df['Credit_History'])
threshold= 3
outliers = df['Credit_History'][abs(z_scores)> threshold]
print(outliers)

z_scores = stats.zscore(df['Family members'])
threshold= 3
outliers = df['Family members'][abs(z_scores)> threshold]
print(outliers)
# Out:
# Series([], Name: LoanAmount applied for (in thoudands), dtype: float64)
# Series([], Name: Loan_Amount_Duration, dtype: float64)
# Series([], Name: Credit_History, dtype: float64)
# Series([], Name: Family members, dtype: float64)

# %%
#Removing the null values

df = df.dropna()

# %%
# Finding the duplicates

df.duplicated()
# Out:
# Series([], dtype: bool)

# %%
# Cleaning the duplicate data

df.drop_duplicates()
# Out:
#            Id  LoanAmount applied for (in thoudands)  Loan_Amount_Duration  \
# 0       31453                                  400.0                 360.0
# 1       21375                                  438.0                 360.0
# 2       27992                                  214.0                 360.0
# 3        3326                                  128.0                 360.0
# 4       22227                                  116.0                  84.0
# ...       ...                                    ...                   ...
# 143563  47852                                    NaN                   NaN
# 143564  47853                                    NaN                   NaN
# 143565  47854                                    NaN                   NaN
# 143566  47855                                    NaN                   NaN
# 143567  47856                                    NaN                   NaN
#
#         Credit_History Property_Area Loan_Status Self_Employed  \
# 0                  1.0     Semiurban           Y           NaN
# 1                  1.0     Semiurban           Y           NaN
# 2                  1.0         Urban           Y           NaN
# 3                  1.0         Urban           Y           NaN
# 4                  0.0         Urban           N           NaN
# ...                ...           ...         ...           ...
# 143563             NaN           NaN         NaN           NaN
# 143564             NaN           NaN         NaN           NaN
# 143565             NaN           NaN         NaN           NaN
# 143566             NaN           NaN         NaN           NaN
# 143567             NaN           NaN         NaN           NaN
#
#         Income of applicant  Income of coapplicant Marital Status  \
# 0                       NaN                    NaN            NaN
# 1                       NaN                    NaN            NaN
# 2                       NaN                    NaN            NaN
# 3                       NaN                    NaN            NaN
# 4                       NaN                    NaN            NaN
# ...                     ...                    ...            ...
# 143563                  NaN                    NaN            Yes
# 143564                  NaN                    NaN            Yes
# 143565                  NaN                    NaN             No
# 143566                  NaN                    NaN            Yes
# 143567                  NaN                    NaN            Yes
#
#        Status of education
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 143563            Graduate
# 143564        Not Graduate
# 143565            Graduate
# 143566            Graduate
# 143567            Graduate
#
# [143568 rows x 11 columns]

# %%
#For finding the outliers in numeric column using Matplotlib
plt.figure(figsize=(14,15))
sns.set_style(style='whitegrid')

    # Plot 1 
plt.subplot(4,3,1)
sns.boxplot(x='LoanAmount applied for (in thoudands)',data=df)

    # Plot 2
plt.subplot(4,3,2)
sns.boxplot(x='Loan_Amount_Duration',data=df)

    # Plot 3 
plt.subplot(4,3,3)
sns.boxplot(x='Credit_History',data=df)

    # Plot 4 
plt.subplot(4,3,4)
sns.boxplot(x='Family members',data=df)
# Out:
# <Axes: xlabel='Family members'>

# %% [markdown]
# # Finding outliers in Objective Column

# %%
df['Self_Employed'].value_counts()
# Out:
# No     39524
# Yes     5787
# Name: Self_Employed, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Male      38399
# Female     8277
# Name: Gender, dtype: int64

# %%
df['Credit_History'].value_counts()
# Out:
# 1.0    36839
# 0.0     7570
# Name: Credit_History, dtype: int64

# %%
df['Family members'].value_counts()
# Out:
# 0.0    27758
# 2.0     7816
# 1.0     7392
# Name: Family members, dtype: int64
